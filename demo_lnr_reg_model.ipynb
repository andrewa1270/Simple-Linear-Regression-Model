# %%
# pip3 install scikit-learn
# pip3 install pandas
# pip3 install seaborn
# pip3 install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline #for visualisation of table
# Out:
# UsageError: unrecognized arguments: #for visualisation of table

# %%
from sklearn.linear_model import LinearRegression

# %%
#read data

data = pd.read_csv('gdp-per-capita-in-the-uk-since-1270.csv')

# %%
#select data from year 1900+
data_post_1900 = data[data['Year'] > 1900]

# %%
#view data from csv
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Entity  747 non-null    object
#  1   Code    747 non-null    object
#  2   Year    747 non-null    int64
#  3   GDP     747 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.5+ KB

# %%
#visua

sns.regplot(x='Year', y='GDP ', data=data_post_1900)
# Out:
# <Axes: xlabel='Year', ylabel='GDP '>

# %%
#regression
#1. create instance of linear regression model
lri = LinearRegression()

# %%
#2. Train the model
lri.fit(data_post_1900[['Year']].values, data_post_1900['GDP '].values)
# Out:
# LinearRegression()

# %%
lri.predict([[2022]])
# Out:
# array([26561.3906507])
